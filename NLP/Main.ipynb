# %%
import nltk
nltk.download('all')

# %%
from nltk.corpus import stopwords

# %%
stopwords.words('english')[0:10]
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're"]

# %%
rawData = open('https://raw.githubusercontent.com/abdullabasim/dataset/main/SMSSpamCollection.tsv').read()

rawData[0:100]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-17-acdd97b0aa20> in <cell line: 1>()
# ----> 1 rawData = open('https://raw.githubusercontent.com/abdullabasim/dataset/main/SMSSpamCollection.tsv').read()
#       2
#       3 rawData[0:100]
#
# FileNotFoundError: [Errno 2] No such file or directory: 'https://raw.githubusercontent.com/abdullabasim/dataset/main/SMSSpamCollection.tsv'
